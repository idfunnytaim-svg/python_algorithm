# %%
# 12일차 : 객체지향과 클래스 기초
# 오늘의 목표
# - 객체지향과 절차지향 프로그래밍에 대해서 이해한다.
# - 클래스를 설계한다.

# 1교시. 객체지향 프로그래밍(OOP) 기초
# - 객체(Object)란?
# - 클래스(Class)란?
# - 객체 생성(인스턴스)
# - 클래스와 객체의 관계
# - 속성(Attribute)과 메서드(Method)
# - self의 의미
# - 생성자 __init__()
# - 객체 생성 및 속성 접근

# 2교시. 딕셔너리와 클래스 비교
# - 딕셔너리로 데이터 관리
# - 딕셔너리에 함수 저장
# - 데이터와 함수의 관계
# - 클래스로 데이터와 기능 묶기
# - 딕셔너리 vs 클래스 비교
# - 데이터 재사용과 코드 중복
# - 클래스가 필요한 이유

# 3교시. 절차지향 vs 객체지향 프로그래밍
# - 프로그래밍 패러다임이란?
# - 절차지향 프로그래밍 개념
# - 객체지향 프로그래밍 개념
# - 절차지향과 객체지향 비교
# - 객체지향의 특징

# 4교시. 클래스 활용 실습
# - 클래스 설계하기
# - 여러 객체 생성하기
# - 객체 리스트 관리
# - 객체 정보 출력
# - 객체의 상태 변경
# - 메서드를 이용한 기능 구현
# - 딕셔너리 기반 프로그램을 클래스로 리팩터링
